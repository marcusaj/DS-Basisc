# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Use dataset about Covid World Vaccination Progress: https://www.kaggle.com/gpreda/covid-world-vaccination-progress

# %%
vacc = pd.read_csv('country_vaccinations.csv')

# %%
vacc
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 20385     Zimbabwe      ZWE  2021-05-20            867396.0
# 20386     Zimbabwe      ZWE  2021-05-21            887928.0
# 20387     Zimbabwe      ZWE  2021-05-22            904073.0
# 20388     Zimbabwe      ZWE  2021-05-23            911033.0
# 20389     Zimbabwe      ZWE  2021-05-24            914921.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %%
#General info about rows and columns
vacc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20390 entries, 0 to 20389
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              20390 non-null  object
#  1   iso_code                             20390 non-null  object
#  2   date                                 20390 non-null  object
#  3   total_vaccinations                   11618 non-null  float64
#  4   people_vaccinated                    10859 non-null  float64
#  5   people_fully_vaccinated              8386 non-null   float64
#  6   daily_vaccinations_raw               9671 non-null   float64
#  7   daily_vaccinations                   20176 non-null  float64
#  8   total_vaccinations_per_hundred       11618 non-null  float64
#  9   people_vaccinated_per_hundred        10859 non-null  float64
#  10  people_fully_vaccinated_per_hundred  8386 non-null   float64
# ...

# %%
#Min for each column
vacc.min()
# Out:
# country                                                                      Afghanistan
# iso_code                                                                             ABW
# date                                                                          2020-12-02
# total_vaccinations                                                                     0
# people_vaccinated                                                                      0
# people_fully_vaccinated                                                                1
# daily_vaccinations_raw                                                                 0
# daily_vaccinations                                                                     0
# total_vaccinations_per_hundred                                                         0
# people_vaccinated_per_hundred                                                          0
# ...

# %%
#Max number of vaccines inoculated per day within all countries from dataset. 
#The number looks too high. Most probably it is a typo.
print("max daily vaccines innoculated:", vacc['daily_vaccinations'].max())
# Out:
# max daily vaccines innoculated: 15860714.0

# %%
#Finding out the country and the date for max daily vaccines innoculated
print("Country with max daily vaccines inoculated:", vacc.loc[vacc['daily_vaccinations'].argmax(), 'country'])
print("Date:", vacc.loc[vacc['daily_vaccinations'].argmax(), 'date'])
# Out:
# Country with max daily vaccines inoculated: China
# Date: 2021-05-25

# %%
#Coutnry with the highest number of people vaccinated
print("Country with highest number of people vaccinated on", vacc.loc[vacc['people_vaccinated'].argmax(), 'date'], ":", vacc.loc[vacc['people_vaccinated'].argmax(), 'country']) 
print( "Total people vaccinated  until that date (inclusive):", vacc['people_vaccinated'].max())
# Out:
# Country with highest number of people vaccinated on 2021-05-25 : United States
# Total people vaccinated  until that date (inclusive): 164378258.0

# %%
#Coutnry with the highest share of people fully vaccinated
print("Country with highest number of people vaccinated on", vacc.loc[vacc['people_fully_vaccinated_per_hundred'].argmax(), 'date'], ":", vacc.loc[vacc['people_fully_vaccinated_per_hundred'].argmax(), 'country']) 
print( "Share of people vaccinated  until that date (inclusive):", vacc['people_fully_vaccinated_per_hundred'].max())
print("the share looks like they vaccinated and their neighbouring countries :)")
# Out:
# Country with highest number of people vaccinated on 2021-05-22 : Gibraltar
# Share of people vaccinated  until that date (inclusive): 110.41
# the share looks like they vaccinated and their neighbouring countries :)

# %%
#Number of people vaccinated in Modolva
print("Number of people vaccinated in Modolva:",vacc.loc[vacc['country']== 'Moldova', 'people_vaccinated'].max())
# Out:
# Number of people vaccinated in Modolva: 301175.0

# %%
#Let's take the subset for Moldova
vaccMD=vacc.loc[vacc['country']== 'Moldova',:]

# %%
vaccMD
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 11897  Moldova      MDA  2021-03-05              3849.0             3849.0
# 11898  Moldova      MDA  2021-03-06                 NaN                NaN
# 11899  Moldova      MDA  2021-03-07                 NaN                NaN
# 11900  Moldova      MDA  2021-03-08                 NaN                NaN
# 11901  Moldova      MDA  2021-03-09                 NaN                NaN
# ...        ...      ...         ...                 ...                ...
# 11974  Moldova      MDA  2021-05-21            288097.0           250034.0
# 11975  Moldova      MDA  2021-05-22            294794.0           256175.0
# 11976  Moldova      MDA  2021-05-23            298553.0           259809.0
# 11977  Moldova      MDA  2021-05-24            306610.0           266238.0
# 11978  Moldova      MDA  2021-05-25            351843.0           301175.0
#
# ...

# %%
#General info about the rows and columns the Moldova's subset
vaccMD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82 entries, 11897 to 11978
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              82 non-null     object
#  1   iso_code                             82 non-null     object
#  2   date                                 82 non-null     object
#  3   total_vaccinations                   57 non-null     float64
#  4   people_vaccinated                    56 non-null     float64
#  5   people_fully_vaccinated              32 non-null     float64
#  6   daily_vaccinations_raw               40 non-null     float64
#  7   daily_vaccinations                   81 non-null     float64
#  8   total_vaccinations_per_hundred       57 non-null     float64
#  9   people_vaccinated_per_hundred        56 non-null     float64
#  10  people_fully_vaccinated_per_hundred  32 non-null     float64
# ...

# %%
#Some descriptive stats about the subset
vaccMD.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count           57.000000          56.000000                32.000000
# mean        121185.824561      108273.142857             23925.968750
# std          96980.152803       83144.912247             11500.132368
# min           3849.000000        3849.000000              7997.000000
# 25%          33885.000000       33094.250000             12652.750000
# 50%          96372.000000       87477.500000             23345.500000
# 75%         185292.000000      163255.750000             33375.250000
# max         351843.000000      301175.000000             50668.000000
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count               40.000000           81.000000
# mean              7110.350000         3640.358025
# std               7235.892887         2678.542679
# min               1225.000000          520.000000
# 25%               2906.000000         1693.000000
# ...

# %%
#Avegare daily vaccinations
print("Avegare daily vaccinations in Moldova:", vaccMD['daily_vaccinations'].mean())
# Out:
# Avegare daily vaccinations in Moldova: 3640.358024691358

# %%
print("Total population vaccinated in Moldova:",vaccMD['people_vaccinated'].max())
# Out:
# Total population vaccinated in Moldova: 301175.0

# %%
#Checking the distribution of the daily vaccinations in Moldova
vaccMD['daily_vaccinations'].hist()
# Out:
# <AxesSubplot:>

# %%
vaccMD[['daily_vaccinations']].boxplot()
# Out:
# <AxesSubplot:>
