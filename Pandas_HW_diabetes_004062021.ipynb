# %%
import numpy as np
import pandas as pd

# %%
db = pd.read_csv('diabetes.csv')

# %%
db
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#Average value per each attribute grouped by types of Pregnancies
db.groupby(['Pregnancies']).mean()
# Out:
#                 Glucose  BloodPressure  SkinThickness     Insulin        BMI  \
# Pregnancies
# 0            123.000000      67.153153      22.270270   81.675676  34.290090
# 1            112.748148      67.792593      24.437037   98.674074  31.372593
# 2            110.796117      63.252427      21.601942   85.844660  30.583495
# 3            123.586667      66.586667      20.080000   87.453333  30.425333
# 4            125.117647      70.029412      15.882353   69.441176  32.141176
# 5            118.859649      76.210526      17.385965   57.298246  33.192982
# 6            120.800000      68.420000      17.640000   63.580000  30.290000
# 7            136.444444      70.777778      20.288889   84.466667  32.631111
# 8            131.736842      75.184211      17.315789   92.815789  31.568421
# 9            131.392857      77.892857      20.892857   62.428571  31.707143
# 10           120.916667      70.208333      15.708333   34.791667  30.641667
# ...

# %%
#Delete one column,but first save it seprately to recover it back after

# %%
#1) Saving column that will be deleted
DPF_column = db['DiabetesPedigreeFunction'].values

# %%
#2) Delete column DiabetesPedigreeFunction
db = db.drop(['DiabetesPedigreeFunction'], axis = 1)

# %%
#Showing that it's not in the db anymore
db
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  Age  \
# 0              6      148             72             35        0  33.6   50
# 1              1       85             66             29        0  26.6   31
# 2              8      183             64              0        0  23.3   32
# 3              1       89             66             23       94  28.1   21
# 4              0      137             40             35      168  43.1   33
# ..           ...      ...            ...            ...      ...   ...  ...
# 763           10      101             76             48      180  32.9   63
# 764            2      122             70             27        0  36.8   27
# 765            5      121             72             23      112  26.2   30
# 766            1      126             60              0        0  30.1   47
# 767            1       93             70             31        0  30.4   23
#
#      Outcome
# 0          1
# 1          0
# ...

# %%
#3) Recovering back column DiabetesPedigreeFunction
db['DiabetesPedigreeFunction'] = DPF_column

# %%
#Showing that it's back again in the db, but as the last column now
db
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  Age  \
# 0              6      148             72             35        0  33.6   50
# 1              1       85             66             29        0  26.6   31
# 2              8      183             64              0        0  23.3   32
# 3              1       89             66             23       94  28.1   21
# 4              0      137             40             35      168  43.1   33
# ..           ...      ...            ...            ...      ...   ...  ...
# 763           10      101             76             48      180  32.9   63
# 764            2      122             70             27        0  36.8   27
# 765            5      121             72             23      112  26.2   30
# 766            1      126             60              0        0  30.1   47
# 767            1       93             70             31        0  30.4   23
#
#      Outcome  DiabetesPedigreeFunction
# ...

# %%
# Shuffle the dataset
db = db.sample(frac=1)
db
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  Age  \
# 382            1      109             60              8      182  25.4   21
# 438            1       97             70             15        0  18.2   21
# 299            8      112             72              0        0  23.6   58
# 165            6      104             74             18      156  29.9   41
# 84             5      137            108              0        0  48.8   37
# ..           ...      ...            ...            ...      ...   ...  ...
# 225            1       87             78             27       32  34.6   22
# 76             7       62             78              0        0  32.6   41
# 700            2      122             76             27      200  35.9   26
# 610            3      106             54             21      158  30.9   24
# 280            0      146             70              0        0  37.9   28
#
#      Outcome  DiabetesPedigreeFunction
# ...

# %%
#Create new column as a flag for normal glucose /abnormal glucose level  and mapping it 
db['NormalGlucoseLevel'] = db['Glucose'].apply(lambda x : x < 200   and x > 80 ).map({True: 1, False: 0})

# %%
db
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  Age  \
# 382            1      109             60              8      182  25.4   21
# 438            1       97             70             15        0  18.2   21
# 299            8      112             72              0        0  23.6   58
# 165            6      104             74             18      156  29.9   41
# 84             5      137            108              0        0  48.8   37
# ..           ...      ...            ...            ...      ...   ...  ...
# 225            1       87             78             27       32  34.6   22
# 76             7       62             78              0        0  32.6   41
# 700            2      122             76             27      200  35.9   26
# 610            3      106             54             21      158  30.9   24
# 280            0      146             70              0        0  37.9   28
#
# ...

# %%
#Calculating how many have normal glucose level and how many has abnormal level
db['NormalGlucoseLevel'].value_counts()
# Out:
# 1    721
# 0     47
# Name: NormalGlucoseLevel, dtype: int64
